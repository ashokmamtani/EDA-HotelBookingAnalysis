# %% [markdown]
# <a href="https://colab.research.google.com/github/ashokmamtani/EDA-HotelBookingAnalysis/blob/main/ProjectCLC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Mounting the drive so that we can access the data
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Import Libraries of  python required for EDA
import numpy as np
import pandas as pd
#from numpy import math
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib import rcParams

# %%
# Load Dataset (Reading of data from the dataset located in the drive)
path="/content/drive/MyDrive/students_data_24oct.csv" # Replace this with the actual path to your file
student_df=pd.read_csv(path)

# %%
#dataset First Look
student_df.head(5)
# Out:
#     Name  Math  Science  English  Attendance
# 0  Priya    80       89       62          65
# 1  Rohan    97       50       87          84
# 2  Kriti    87       73       78          63
# 3   Amit    59       88       98          69
# 4  Sneha    62       80       71          82

# %%
student_df['Total']=(student_df['Math']+student_df['Science']+student_df['English'])
student_df['average']=(student_df['Math']+student_df['Science']+student_df['English'])/3
# Out:
#     Total    average
# 0     231  77.000000
# 1     234  78.000000
# 2     238  79.333333
# 3     245  81.666667
# 4     213  71.000000
# ..    ...        ...
# 95    224  74.666667
# 96    223  74.333333
# 97    243  81.000000
# 98    253  84.333333
# 99    258  86.000000
#
# [100 rows x 2 columns]

# %%
#Class Average of Each Subject
M=student_df['Math'].mean()
S=student_df['Science'].mean()
E=student_df['English'].mean()
print("Maths Average Marks",M,"\nScience Average Marks" ,S, "\nAverage English Marks", E)
# Out:
# Maths Average Marks 76.25
# Science Average Marks 75.86
# Average English Marks 74.26

# %%
#Highest and Lowest Marks fro each Subject
MMax=student_df['Math'].max( )
SMax=student_df['Science'].max( )
EMax=student_df['English'].max( )
MMin=student_df['Math'].min()
SMin=student_df['Science'].min()
EMin=student_df['English'].min()
print ("Max. Marks for each Subject" )
print(" Math :", MMax, "Science",SMax, "English ",EMax)

print ("Min. Marks for each Subject" )
print(" Math :", MMin, "Science",SMin, "English ",EMin)
# Out:
# Max. Marks for each Subject
#  Math : 99 Science 100 English  100
# Min. Marks for each Subject
#  Math : 50 Science 50 English  50

# %%
#Top three students based on average
student_df.sort_values(by=['average'],ascending=False).head(3)
# Out:
#      Name  Math  Science  English  Attendance    average  Total
# 51   Yash    99       87       97          87  94.333333    283
# 70  Mehul    87       93       98          76  92.666667    278
# 9   Rahul    84       93       99          89  92.000000    276

# %%
#Display Student with Attendance less than 75 %
df=student_df[student_df['Attendance']<75]
df[['Name', 'Attendance']]
# Out:
#         Name  Attendance
# 0      Priya          65
# 2      Kriti          63
# 3       Amit          69
# 6       Neha          71
# 7      Arjun          73
# 14     Karan          72
# 16      Ritu          70
# 17     Ankit          64
# 19     Mohit          62
# 22     Sanya          65
# 25      Ravi          73
# 30    Anjali          65
# 32     Komal          66
# 33     Vivek          72
# 45    Mukesh          66
# 47     Jyoti          63
# 48    Snehal          73
# 49     Naman          72
# 50     Kajal          62
# 53     Irfan          72
# 56     Kabir          61
# 58    Ramesh          70
# 60    Rachit          71
# 62     Rupal          63
# 63      Alok          64
# 64    Shreya          63
# 69    Ananya          69
# 71       Ira          62
# 72      Tara          64
# 83    Gautam          63
# 84    Chirag          65
# 86   Dheeraj          69
# 87  Vaishali          67
# 90    Kushal          68
# 94    Harini          63
# 96      Aman          63
# ...

# %%
# Bar Chart showing average marks of each student
plt.figure(figsize=(17, 6))
student_df['average'].plot(kind='bar')
# Out:
# <Axes: >

# %%
#store the datafram in a csv file
student_df.to_csv("student_summary.csv.")
