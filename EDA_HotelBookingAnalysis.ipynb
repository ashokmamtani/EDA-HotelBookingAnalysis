# %% [markdown]
# <a href="https://colab.research.google.com/github/ashokmamtani/EDA-HotelBookingAnalysis/blob/main/EDA_HotelBookingAnalysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Summary -**
# <p  align="justify">This project contains the real-world data record of hotel bookings of a city and a resort hotel containing details like bookings, cancellations, guest details, etc. from 2015 to 2017.Have you ever wondered about the trends for hotel bookings? How long people stay? How often people cancel? What are the busiest months? In this analysis we explore a large dataset to examine these questions.

# %% [markdown]
# ![download.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# ## **Project Type**- **EDA Hotel Booking Analysis using Python language**
# ### **Contribution**    - Individual
# ### **Team Member** - Ashok Mamtani

# %% [markdown]
# <P align="justify">The Hotel Bookings dataset is a comprehensive collection of information regarding hotel bookings, cancellations, and guests' details. This dataset provides insights into various aspects such as the type of hotel, the number of adults, children and babies per booking, the length of stay in both weekend nights (Saturday or Sunday) and weekdays (Monday to Friday), the meal plan chosen by guests, their country of origin and market segment designation.
# Additionally, this dataset includes significant information about reservation status and its updates. It covers whether a booking was canceled or not, the lead time between booking date and arrival date, the week number and day of arrival date. It also indicates if a guest is a repeated visitor or a new customer.
#
# <p  align="Justify">The dataset contains information related to room assignments as well. It mentions both reserved room types (the type of room initially requested) as well as assigned room types (the room actually allocated). Furthermore, it reveals any changes made to bookings along with details about previous cancellations made by guests.
#
# <p  align="Justify">Other relevant factors in this dataset are deposit type for each booking; ID numbers for travel agencies used in making reservations; days spent on waiting lists before confirmation; customer classification such as transient or group; average daily rate calculated based on lodging transactions divided by total staying nights; required car parking spaces indicated by customers; the total count of special requests made by each guest.
# <p  align="Justify"> The provided data can facilitate analysis on several levels: studying specific hotels within different periods (including year), understanding trends across months and weeks within those years to identify preferred seasons among guests from various countries represented in terms of proportions over other nations. An examination can be conducted for differences between adult-only bookings vs family-oriented ones considering associated variables like stayed weekend/week nights for conversations around how these two groups differ when it comes to selecting their staying patterns at hotels.
#
# <p  align="Justify">This expansive dataset has great potential for an in-depth exploration into various aspects involved in hotel bookings processes while providing valuable insights for improving hotel services, optimizing operations, and understanding customer preferences</p>

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# https://github.com/ashokmamtani/EDA-HotelBookingAnalysis/blob/main/EDA_HotelBookingAnalysis.ipynb

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# **Write Problem Statement Here.**

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# <p  align="Justify">The hotel industry plays a critical role in the success of the hospitality and tourism sectors. As competition in the market grows, hotel business owners need to understand their hotel's performance and develop effective marketing strategies to increase visibility.
#
# <p  align="Justify">To achieve this, hotels need to analyze historical trends and customer behavior to gain valuable insights and inform data-driven marketing campaigns. By leveraging this information and implementing well-planned marketing strategies, hotels can boost their performance and revenue, ensuring continued success in the highly competitive hospitality industry. <br>
#
# <p  align="Justify">In the past few years, both the City Hotel and Resort Hotel have experienced significant increases in their cancellation rates. As a result, both hotels are currently facing a range of challenges, such as reduced revenue and underutilized hotel rooms. Therefore, the top priority for both hotels is to reduce their cancellation rates, which will enhance their efficiency in generating revenue. This report focuses on the analysis of hotel booking cancellations and other factors that do not directly impact their business and annual revenue generation.
#
# <p  align="Justify">The main aim of the project is to understand and visualize datasets from the hotel and customer point of view i.e.reasons for booking cancellations across various parameters best time to book a hotel peak season.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
# ```
# # Chart visualization code
# ```
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
#Mounting the drive so that we can access the data
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # **Brief Introduction of library used in completing this project**
# In this project, We used Python's most useful libraries like Pandas, Matplotlib, Seaborn etc. to examine, cleaning and to analyse the “Hotel Booking Analysis” dataset.

# %%
# Import Libraries of  python required for EDA
import numpy as np
import pandas as pd
#from numpy import math
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib import rcParams
import datetime

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset (Reading of data from the dataset located in the drive)
path='/content/drive/MyDrive/TECHMINDEDU/DataSets/data sets/Hotel booking-20241023T162656Z-001/Hotel booking/Hotel Bookings.csv'
hotel_booking_df=pd.read_csv(path)

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look (lets check the data by looking the first 5 rows )
hotel_booking_df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# ...

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
hotel_booking_df.shape
# Out:
# (119390, 32)

# %% [markdown]
# This dataset contains 119390 rows and 32 columns

# %%
hotel_booking_df.sample(5)
# Out:
#               hotel  is_canceled  lead_time  arrival_date_year  \
# 45212    City Hotel            1         50               2015
# 2342   Resort Hotel            0         10               2015
# 64770    City Hotel            1        615               2017
# 77558    City Hotel            1          0               2015
# 29706  Resort Hotel            0         45               2016
#
#       arrival_date_month  arrival_date_week_number  arrival_date_day_of_month  \
# 45212            October                        43                         24
# 2342             October                        41                          9
# 64770              March                        11                         16
# 77558          September                        39                         22
# 29706            October                        44                         29
#
#        stays_in_weekend_nights  stays_in_week_nights  adults  ...  \
# ...

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
hotel_booking_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %% [markdown]
#  # Removing Duplicate Values

# %%
# Dataset Duplicate Value Count
hotel_booking_df.duplicated().value_counts()
# Out:
# False    87396
# True     31994
# Name: count, dtype: int64

# %%
#Removing Duplicate Rows
hotel_booking_df.drop_duplicates(inplace = True)
hotel_booking_df.shape
# Out:
# (87396, 32)

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
null_counts = hotel_booking_df.isnull().sum()
null_columns = null_counts[null_counts > 0]
print(null_columns.sort_values(ascending=False),"\n")
print(f"{len(null_columns)} columns have null values.")
# Out:
# company     82137
# agent       12193
# country       452
# children        4
# dtype: int64
#
# 4 columns have null values.

# %%
# Handing null values of column agent and company
# Most rows in company and agent columns are missing , we will drop these both columns
hotel_booking_df = hotel_booking_df.drop(['company', 'agent'],  axis=1)

#filling the null values of country with mode
hotel_booking_df['country']=hotel_booking_df['country'].fillna(hotel_booking_df['country'].mode())

#adding null value of children column to 0 as there are four rows in dataset so it will not affect much . we can delete these four rows also. Hear i have find mean value
hotel_booking_df['children']=hotel_booking_df['children'].fillna(hotel_booking_df['children'].mean())

# %%
#Filling Numeric value
#hotel_booking_df[~df['agent'].isna( )]

# %%
# Visualizing the missing values
#all missing values are removed

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# This dataset contains 119390 observations for a City Hotel and a Resort Hotel. Each observation represents a hotel booking between the 1st of July 2015 and 31st of August 2017, including booking that effectively arrived and booking that were canceled.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
#creating a list of columns available in dataset finally
listofcols=list(hotel_booking_df.columns)
listofcols
# Out:
# ['hotel',
#  'is_canceled',
#  'lead_time',
#  'arrival_date_year',
#  'arrival_date_month',
#  'arrival_date_week_number',
#  'arrival_date_day_of_month',
#  'stays_in_weekend_nights',
#  'stays_in_week_nights',
#  'adults',
#  'children',
#  'babies',
#  'meal',
#  'country',
#  'market_segment',
#  'distribution_channel',
#  'is_repeated_guest',
#  'previous_cancellations',
#  'previous_bookings_not_canceled',
#  'reserved_room_type',
#  'assigned_room_type',
#  'booking_changes',
#  'deposit_type',
#  'days_in_waiting_list',
#  'customer_type',
#  'adr',
#  'required_car_parking_spaces',
#  'total_of_special_requests',
#  'reservation_status',
#  'reservation_status_date']

# %%
# Dataset Describe
hotel_booking_df.describe().T              #This function  gives numerical information information
# Out:
#                                   count         mean        std      min  \
# is_canceled                     87396.0     0.274898   0.446466     0.00
# lead_time                       87396.0    79.891368  86.052325     0.00
# arrival_date_year               87396.0  2016.210296   0.686102  2015.00
# arrival_date_week_number        87396.0    26.838334  13.674572     1.00
# arrival_date_day_of_month       87396.0    15.815541   8.835146     1.00
# stays_in_weekend_nights         87396.0     1.005263   1.031921     0.00
# stays_in_week_nights            87396.0     2.625395   2.053584     0.00
# adults                          87396.0     1.875795   0.626500     0.00
# children                        87396.0     0.138640   0.455870     0.00
# babies                          87396.0     0.010824   0.113597     0.00
# is_repeated_guest               87396.0     0.039075   0.193775     0.00
# previous_cancellations          87396.0     0.030413   0.369145     0.00
# ...

# %% [markdown]
# ### Variables Description

# %% [markdown]
# Columns:
#
# **hotel**: One of the hotels is a resort hotel and the other is a city hotel.
#
# **is_canceled** lead_time: Value indicating if the booking was canceled (1) or not (0).
#
# **arrival_date_year**: Year of arrival date.
#
# **arrival_date_month**: Month of arrival date with 12 categories: “January” to “December”.
#
# **arrival_date_week_number**: Week number of the arrival date.
#
# **arrival_date_day_of_month**: Day of the month of the arrival date.
#
# **stays_in_weekend_nights**: Number of weekend nights (Saturday or Sunday) the
#
# guest stayed or booked to stay at the hotel.
#
# **stays_in_week_nights**: Number of week nights (Monday to Friday) the guest stayed.
#
# **adults**: Number of adults
#
# **children**: Number of Childern
#
# **babies**: Number of Babies
#
# **meal**: BB – Bed & Breakfast
#
# **country**: Country of origin.
#
# **market_segment**: Market segment designation. In categories, the term “TA” means  “Travel Agents” and “TO” means “Tour Operators”
#
# **distribution_channel**: Booking distribution channel. The term “TA” means “Travel Agents” and “TO” means “Tour Operators”
#
# **is_repeated_guest**: Value indicating if the booking name was from a repeated guest (1) or not (0)
#
# **previous_cancellations**: Number of previous bookings that were cancelled by the customer prior to the current booking
#
# **previous_bookings_not_canceled**: Number of previous bookings not cancelled by the customer prior to the current booking
#
# **reserved_room_type**: Code of room type reserved. Code is presented instead of designation for anonymity reasons.
#
# **assigned_room_type**: Code for the type of room assigned to the booking. Sometimes the assigned room type differs from the reserved room type due to hotel operation reasons (e.g. overbooking) or by customer request. Code is presented instead of designation for anonymity reasons
#
# **booking_changes**: Number of changes/amendments made to the booking.
#
# **deposit_type**: No Deposit – no deposit was made; Non Refund – a deposit was made in the value of the total stay cost; Refundable – a deposit was made with a value under the total cost of stay.
#
# **agent**: ID of the travel agency that made the booking
#
# **company**: ID of the company/entity that made the booking or responsible for paying the booking. ID is presented instead of designation for anonymity reasons
# days_in_waiting_list: Number of days the booking was in the waiting list before it was confirmed to the customer
#
# **customer_type**: Group – when the booking is associated to a group; Transient – when the booking is not part of a group or contract, and is not associated to other transient booking; Transient-party – when the booking is transient, but is associated to at least other transient booking
#
# **adr**: Average Daily Rate (Calculated by dividing the sum of all lodging transactions by the total number of staying nights)
#
# **required_car_parking_spaces**: Number of car parking spaces required by the customer
#
# **total_of_special_requests**: Number of special requests made by the customer (e.g. twin bed or high floor)
#
# **reservation_status**: Check-Out – customer has checked in but already departed; No-Show – customer did not check-in and did inform the hotel of the reason why
#
# **reservation_status_date**: Date at which the last status was set. This variable can be used in conjunction with the ReservationStatus to understand when was the booking canceled or when did the customer checked-out of the hotel

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
L = hotel_booking_df.columns.to_list()
for i in L:
    print(f'the number of unique values of {i} is {len(hotel_booking_df[i].unique())}')
    values_counts = pd.DataFrame(hotel_booking_df[i].value_counts())
    print(f'the values of the {i} are : \n{values_counts}')
    print('=========================================')
# Out:
# the number of unique values of hotel is 2
# the values of the hotel are :
#               count
# hotel
# City Hotel    53428
# Resort Hotel  33968
# ...
# the number of unique values of is_canceled is 2
# the values of the is_canceled are :
#              count
# is_canceled
# 0            63371
# 1            24025
# ...
# the number of unique values of lead_time is 479
# the values of the lead_time are :
#            count
# lead_time
# 0           5978
# 1           3216
# 2           1927
# 3           1704
# 4           1570
# ...          ...
# 410            1
# 411            1
# 371            1
# 532            1
# 463            1
#
# [479 rows x 1 columns]
# ...
# the number of unique values of arrival_date_year is 3
# the values of the arrival_date_year are :
#                    count
# arrival_date_year
# 2016               42391
# 2017               31692
# 2015               13313
# ...
# the number of unique values of arrival_date_month is 12
# the values of the arrival_date_month are :
# ...

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %% [markdown]
# ## Removing Some irrelevant Rows

# %%
# Here some of the rows with total number of adults, children or babies equal to zero.
print(hotel_booking_df[hotel_booking_df.adults + hotel_booking_df.babies + hotel_booking_df.children == 0].shape)

#Here, there are 166 rows , so we will remove such rows.
hotel_booking_df.drop( hotel_booking_df[(hotel_booking_df.adults==0) & (hotel_booking_df.children==0) & (hotel_booking_df.babies==0)].index, inplace=True)
#hotel_booking_df[(hotel_booking_df ['adults']==0 )& (hotel_booking_df['children']==0) & (hotel_booking_df['babies']==0)].shape
# Out:
# (166, 30)

# %% [markdown]
# ## Changing datatypes

# %%
#turn column into int data type
hotel_booking_df['children'].astype(int)
#turn column into datetime data type
pd.to_datetime(hotel_booking_df['reservation_status_date'])
# Out:
# 0        2015-07-01
# 1        2015-07-01
# 2        2015-07-02
# 3        2015-07-02
# 4        2015-07-03
#             ...
# 119385   2017-09-06
# 119386   2017-09-07
# 119387   2017-09-07
# 119388   2017-09-07
# 119389   2017-09-07
# Name: reservation_status_date, Length: 87230, dtype: datetime64[ns]

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# ## Create new columns by combining other columns

# %%
#create total night column
hotel_booking_df['total_night'] = hotel_booking_df['stays_in_weekend_nights'] + hotel_booking_df['stays_in_weekend_nights']

#convert month name to number then create new arrival date column by combining year month date
hotel_booking_df['arrival_date_monthno'] = pd.to_datetime(hotel_booking_df['arrival_date_month'] , format='%B').dt.month
hotel_booking_df['arrival_date'] = pd.to_datetime(dict( year = hotel_booking_df.arrival_date_year, month = hotel_booking_df.arrival_date_monthno,  day=hotel_booking_df.arrival_date_day_of_month))

#Converting "adults," "children," and "babies" to total_people by adding it
hotel_booking_df['total_people']= hotel_booking_df['adults']+ hotel_booking_df['children']+ hotel_booking_df['babies']

# Creating 'total_childrens' variable by adding 'chldrens' and 'babies' variables
hotel_booking_df['total_childrens']= hotel_booking_df['children']+ hotel_booking_df['babies']

# Creating 'reserved_room_assigned' variable which describe same room assigned or not
hotel_booking_df['reserved_room_assigned']=np.where(hotel_booking_df['reserved_room_type']==hotel_booking_df['assigned_room_type'], 'yes', 'no')

#Creating 'guest_category' from variable 'total_people'
hotel_booking_df['guest_category']=np.where(hotel_booking_df['total_people']==1, 'single',np.where(hotel_booking_df['total_people']==2, 'couple', 'family'))

# Creating 'lead_time_category' from 'lead_time' variale to display category
hotel_booking_df['lead_time_category']=np.where(hotel_booking_df['lead_time']<=15, 'low',np.where((hotel_booking_df['lead_time']>15) & (hotel_booking_df['lead_time']<90), 'medium', 'high'))

# %%
# Coverting datatype of variables total_people and total_childrens to int64 from float64
hotel_booking_df['total_people']=hotel_booking_df['total_people'].astype('int64')
hotel_booking_df['total_childrens']=hotel_booking_df['total_childrens'].astype('int64')


#Checking datatype of total_column
hotel_booking_df[['total_people','total_childrens']].info()
hotel_booking_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 87230 entries, 0 to 119389
# Data columns (total 2 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   total_people     87230 non-null  int64
#  1   total_childrens  87230 non-null  int64
# dtypes: int64(2)
# memory usage: 2.0 MB
# <class 'pandas.core.frame.DataFrame'>
# Index: 87230 entries, 0 to 119389
# Data columns (total 38 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   hotel                           87230 non-null  object
#  1   is_canceled                     87230 non-null  int64
#  2   lead_time                       87230 non-null  int64
#  3   arrival_date_year               87230 non-null  int64
#  4   arrival_date_month              87230 non-null  object
#  5   arrival_date_week_number        87230 non-null  int64
#  6   arrival_date_day_of_month       87230 non-null  int64
# ...

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# ###**Question-1-What are the most popular hotels ?**

# %%
#code to find the popupularity of each type of hotel
plt.figure(figsize=(5,6), facecolor='pink')
#counting the bookings only by removing the canceled bookings
df=hotel_booking_df[hotel_booking_df['is_canceled']==0]['hotel'].value_counts()
plt.pie(list(df.values), labels=df.index,  explode=[0,0.2], autopct='%.1f%%' )
plt.legend(loc=1, fontsize=10)
plt.title('Booking Percentage of Hotel type', fontweight='bold' , size=20)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# <p  align='justify'>This pie chart is utilised here to show which type of  hotel is preferred by the people.Pie charts make sense to show a parts-to-whole relationship for categorical data, including ordinal and nominal data. The slices in the pie typically represent percentages of the total. With ordinal data, a type of categorical data, the sample is often divided into groups, and the responses have a defined order.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# ######<Li> It is clearly visible from pie chart that majority of people prefer to book city hotel compared to Resort hotels <br> <li>A city hotel was most preferred by 60  percent of customers over a resort.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# answer here

# %% [markdown]
# ###**Question-2-How many booking Hotels have over the year?**

# %%
plt.figure(figsize = (4,6), facecolor="pink")
plt.title('Booking v/s Year', color='k', fontsize =20)
hotel_booking_df['reservation_status_date']= pd.to_datetime(hotel_booking_df['reservation_status_date'])
hotel_booking_df['year']= hotel_booking_df['reservation_status_date'].dt.year
data = hotel_booking_df[hotel_booking_df['is_canceled'] == 0].groupby('year')['hotel'].count().reset_index()
sns.barplot(x='year',y='hotel', data = data, color='blue',width=0.5 )
#plt.legend(fontsize = 20)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# ***A bar chart plots numeric values for levels of a categorical feature as bars. Levels are plotted on one chart axis, and values are plotted on the other axis. Here , x-axis is used for the year and y axis is used for count of bookings in the years***

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# ***Bookings for City hotels are higher than Resort hotels over the years and in year 2016 the bookings for both the hotels were maximum***

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# ### **Question-3-What is the cancellation rate in City Hotels**

# %%
#finding the number of bookings canceled in the city hotel
dfcity=hotel_booking_df[hotel_booking_df['hotel']=='City Hotel']['is_canceled'].value_counts()
dfcity
# Out:
# is_canceled
# 0    37239
# 1    16035
# Name: count, dtype: int64

# %%
dfcity=hotel_booking_df[hotel_booking_df['hotel']=='City Hotel']['is_canceled'].value_counts()
colors = sns.color_palette('bright')
#colors = sns.color_palette(["#FFEC9E", "#FFBB70"])
plt.figure(figsize = (5,3),facecolor="pink")
plt.title('Reservation Status for City Hotels Type')
plt.bar(['Not cancelled' , 'Cancelled'],dfcity, edgecolor = 'k', width = 0.1, color=colors)

plt.show()

# %%
dfcity=hotel_booking_df[hotel_booking_df['hotel']=='City Hotel']['is_canceled'].value_counts()
dfcity.plot(kind='pie' , labels='is_canceled', autopct="%0.2f%%")
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# ***Here the bar graph is used to show the distribution of city hotel data.***

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# ***With the help of this bar graph, we can conclude that 37000 of customers checked-in to the city hotel while 16000 of customers canceled their bookings<br>From Pie graph, it is evident that 70 % customers check-in after booking and only 30% cancel.<br>It is clear that  In city Hotel, cancellation rate is 30 %***

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# ###**Question-4-What is the cancellation rate in Resort Hotels**

# %%
# Chart - 2 visualization code

dfR=hotel_booking_df[hotel_booking_df['hotel']=='Resort Hotel']['is_canceled'].value_counts()
colors = sns.color_palette(["#FFEC9E", "#FFBB70"])
plt.figure(figsize = (5,3),facecolor="#C38154")
plt.title('Reservation Status for Resort Hotels Type')
plt.bar(['Not cancelled' , 'Cancelled'],dfR, edgecolor = 'k', width = 0.2,color=colors)
plt.show()

# %%
dfR.value_counts()
# Out:
# count
# 25982    1
# 7974     1
# Name: count, dtype: int64

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# ***Here the bar graph is used to show the distribution of city hotel data.***

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# ***In Resort type Hotels, cancellation rate is 30 %.***

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# ###**Question-5-What is the bookings and Cancellation Status for each kind of hotel**

# %%
# Chart - 3
plt.figure(figsize=(5,3), facecolor='pink')
ax1 = sns.countplot(x=hotel_booking_df['hotel'],  hue='is_canceled', data= hotel_booking_df, palette='tab10' , width=0.2)
legend_lebels,_ = ax1.get_legend_handles_labels()
plt.title('Bookings and Cancellation Status for each type of Hotel', size = 20)
plt.xlabel('Hotel Type',size=25)
plt.ylabel('Number of Arrivals')
plt.legend(['Not Canceled','Canceld'])
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# ***used multiple bar chart to analysis the cancellation and booking counts for each type of hotel in one single chart***

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# ***This graph shows that the city hotel has more bookings as well as more cancellation compared to Hotel Resorts type. <BR>***

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# ###**Question-6-Which are the months which experiences cancellations more ?**

# %%
#  Month wise data of  Bookings and Cancellations in hotels
plt.figure(figsize=(12,5), facecolor='pink')
ax1 = sns.countplot(x=hotel_booking_df['arrival_date_month'], hue='is_canceled', data= hotel_booking_df, palette = 'tab10')
legend_lebels,_ = ax1.get_legend_handles_labels()
plt.title(' Hotel Bookings  Per Month', size = 20)
plt.xlabel('month',size=15)
plt.ylabel('Number of Bookings')
plt.legend(['Not Canceled','Canceld'])
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# ***A simple bar chart showing booking trends over time in months . ***

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# ***By the graph, we  can observe that most of the Bookings are occuring in the month of July an August and continues till Oct.***

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# ###**Question-7-What are the comman arival dates?**

# %%
plt.figure(figsize=(12,5), facecolor='pink')
sns.lineplot(data=hotel_booking_df,x='arrival_date_month',y='arrival_date_year')
plt.xlabel('Arrival date month')
plt.ylabel('Arrival date year')
plt.title('Hotel With booking year', size=20)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# ***A line chart is most suitable when one wants to visualize changes in data over time, or when one wants to show relationships between continuous variables.<br>
# Here also we are comparing ADR with the time(day,month, year)*** .

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# ***Peak point on January
# And the Continue to feb to june***

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# ###**Question-8-Which room generates a higher ADR??**

# %%
# Plotting box plot assigned_room_type against ADR
plt.figure(figsize=(15,8))
ax=sns.boxplot(x=hotel_booking_df['assigned_room_type'], y=hotel_booking_df['adr'])
ax.set_title('Box plot of assigned_room_type v/s adr')
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# ***A boxplot is plotted for each room type wrt to adr and compared the adr of every room type***

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# ***Room types G, followed by H, generate high ADR. Room I has a very low ADR. The most popular room is A, but it has a lower ADR than other room types that are less popular with customers for bookings. To maximize revenue, the hotel should increase the number of rooms in A, G and H.***

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# ###**Question-9-Which are the top 10 counties from where the guests are cancelling their bookings?**

# %%
cancelled_data= hotel_booking_df[hotel_booking_df['is_canceled']==1]
top_10_country = cancelled_data['country'].value_counts()[:10]
custom_colors = ['#FF6347', '#4682B4', '#7FFF00', '#FFD700', '#87CEEB', '#FFA07A', '#6A5ACD', '#FF69B4', '#40E0D0', '#DAA520']
plt.figure(figsize=(8, 8), facecolor='pink')  # Set background color to a light brown
plt.title('Top 10 countries with reservation canceled', color="black")
plt.pie(top_10_country, autopct='%.2f', labels=top_10_country.index, colors=custom_colors)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A pie chart is best choice to show the percentage wise the values of categorical values distribution . so it is the best plot in this case

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# <Li> 50% percent guests are visiting from the the country PRT

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# ###**Question-10-How doe the ADR is varing over the month?**

# %%
plt.figure(figsize = (10,6), facecolor="pink")
plt.title('ADR v/s Month', color='k',fontsize =30)
hotel_booking_df['reservation_status_date']= pd.to_datetime(hotel_booking_df['reservation_status_date'])
hotel_booking_df['month']= hotel_booking_df['reservation_status_date'].dt.month
data = hotel_booking_df[hotel_booking_df['is_canceled'] == 1].groupby('month')['adr'].sum().reset_index()
#data2=hotel_booking_df[hotel_booking_df['is_canceled'] == 1].groupby('month')['hotel'].count().reset_index()
sns.lineplot(x='month', y='adr', data = data, color='red' )
#sns.barplot(x='month', y='hotel', data = data2, color='blue' )
#plt.legend(fontsize = 20)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# ***Line chart is used for a trend over the time***

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# ***Revenues of the both type of  Hotels increased during summer in the month of july and august and decreased in winter.***

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# ### **Question-11-How many hotel room canceled after booking ?**

# %%
plt.figure(figsize=(8,6), facecolor='pink')
ax1 = sns.countplot(x=hotel_booking_df['assigned_room_type'],  hue='is_canceled', data= hotel_booking_df, palette='tab10' , width=0.5)
legend_lebels,_ = ax1.get_legend_handles_labels()
plt.title('Bookings and Cancellation Status for each type of assigned Room type', size = 20)
plt.xlabel('Hotel Type',size=25)
plt.ylabel('Number of Arrivals')
plt.legend(['Not Canceled','Canceld'])
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# ***Bar chart is used.***

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# ***It's clearly seen that the most people preferred Type A, type of room.***

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# ###**Question-12-What is the preferred meal plan of customers who have done bookings ?**

# %%
# Chart - 9 visualization code
plt.figure(figsize=(10,6))
mealtype=hotel_booking_df[hotel_booking_df['is_canceled']==0]['meal'].value_counts()
palette_color = sns.color_palette('bright')
MT=["BB=Bed & BF","FB=FULL BOARD", "UNDEFIND= NO MEAL", "HB-HALFBOAR"]
plt.pie(list(mealtype.values), labels=list(mealtype.index), colors=palette_color, autopct='%.0f%%')
plt.title("Favourite Food Type",fontweight="bold",size=20)
plt.legend(loc=1)
plt.show()

# %% [markdown]
# - RO: Room only
#
# - SC: Self Catering
#
# - BB: Bed & Breakfast
#
# - HB: Half Board (Breakfast and Dinner normally)
#
# - FB: Full Board (Beakfast, Lunch and Dinner)
#
# - AI: All Inclusive (all services of full board plus any others specified in each case)

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# **Pie chart is used**

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# <h3> Type of meal plan</h3>
# <Li> BB --bed and breakfast.
# <li>  HB--half board (in which breakfast and dinner are included.)
# <li> FB--full board (in which breakfast, lunch and dinner are included.)
#
# **As we can see 79% of people prefer 'BB' type meal.**

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# ###**Question-13-What are the most effective booking channels?**

# %%
# Chart - 10 visualization code
plt.figure(figsize=(8,6), facecolor='pink')
ax1 = sns.countplot(x=hotel_booking_df['distribution_channel'],  hue='is_canceled', data= hotel_booking_df, palette='tab10' , width=0.5)
legend_lebels,_ = ax1.get_legend_handles_labels()
plt.title('Bookings and Cancellation Status for Each distribution_channel type', size = 20)
plt.xlabel('Distribution',size=25)
plt.ylabel('Number of Arrivals')
plt.legend(['Not Canceled','Canceld'])
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I have used Bar chart to analyse the quesiton

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# <li> Most of the booking were done by TA /TO .
# <li> GDS can be removed .

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# ###**Question-14-What is the big picture of room booking over year and month** ?

# %%
# Chart - 11 visualization code
df_book = hotel_booking_df.groupby(['arrival_date_year','reservation_status'])['reservation_status'].count().unstack()
df_book.plot(kind='bar')
plt.title('Hotel Booking Analysis Year wise', size=20)
plt.xlabel('Year of Booking')
plt.ylabel('Counts of Resevations')
# Out:
# Text(0, 0.5, 'Counts of Resevations')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **Room booking in three-year period:
# <LI> Most rooms are check out while there are still big proportion of rooms are being canceled.
# <li> The number of of rooms that are booked but the customers were not show up was inconsiderable.**

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# ###**Question-15-How Car Parking Space availablity is affecting the cancellation of boookings**

# %%
plt.figure(figsize=(5,3) , facecolor='pink')
ax1 = sns.countplot(x=hotel_booking_df['required_car_parking_spaces'],  hue='is_canceled', data= hotel_booking_df, palette='tab10' , width=0.3)
legend_lebels,_ = ax1.get_legend_handles_labels()
plt.title('BookingsStatus  v/s Required_car_parking_spaces', size = 20)
plt.xlabel('Car Parking Required',size=25)
#plt.xticks(hotel_booking_df['required_car_parking_space'],['C','NC'])
plt.ylabel('Number of Bookings')
plt.legend(['Not Canceled','Canceld'])
plt.show()

# %%
hotel_booking_df.required_car_parking_spaces.value_counts().plot(kind='pie' ,autopct='%0.02f%%')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# <li>Here I have used bar graph to analyse how the car parking facility affects the cancelllation
# <li> pie chart to find the percentage of people needing car parking space along with booking **

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# <li> As, we can see from this graph that most of bookings do not require Car Parking space
#  <li>and only 8% need parking <br>
#  <li> so it is least affecting the cancellation of bookings***.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# ###**Question-16-How many parking spaces are most frequently requested by customers?**

# %%
# Plotting count plot for number of requested parking spaces in terms of hotel
plt.figure(figsize=(7,5))
ax=sns.countplot(x=hotel_booking_df['required_car_parking_spaces'], hue=hotel_booking_df['hotel'])
ax.set_title('number of parking spaces requested by customers in terms of hotel types')
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# ***Here I picked the countplot grapht to count the number of parking spaces required by the customers***

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# ***Most of the customers (91.63%) did not request any parking spaces. Only a few customers (8.31%) requested parking. One parking space is most desirable to customers. The hotel can eliminate parking spaces 3 and 8 and concentrate on parking spaces 1 and 2, which will reduce the cost of providing parking spaces.***

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# ****

# %% [markdown]
# ###**Question-17-How Special Requests is affecting the cancellation of boookings**

# %%
plt.figure(figsize=(5,3) , facecolor='pink')
ax1 = sns.countplot(x=hotel_booking_df['total_of_special_requests'],  hue='is_canceled', data= hotel_booking_df, palette='tab10' , width=0.3)
legend_lebels,_ = ax1.get_legend_handles_labels()
plt.title('Bookings Status  v/s Total_of_special_requests', size = 20)
plt.xlabel('total_of_special_requests',size=10)
#plt.xticks(hotel_booking_df['required_car_parking_space'],['C','NC'])
plt.ylabel('Number of Bookings')
plt.legend(['Not Canceled','Canceld'])
plt.show()
#hotel_booking_df.required_car_parking_spaces.value_counts()

# %%
hotel_booking_df['total_of_special_requests'].value_counts().plot(kind='pie' , autopct='%0.2f%%')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# ***Here I have used bar graph  to analyse how the total_of_special_request facility affects the cancelllation <br>
# and pie chart to measure the percentage of total_of_services***

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **As, we can see from this graph that total of special request is marginally affecting the bookings.**

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# ###**Question-18-Which type of booking is prefered by customers?**

# %%
# Percentage distribution of Deposite type
hotel_booking_df['deposit_type'].value_counts(normalize=True) * 100
# Out:
# deposit_type
# No Deposit    98.687378
# Non Refund     1.189958
# Refundable     0.122664
# Name: proportion, dtype: float64

# %%
# Plotting the graph showing the count of different types of deposit
sns.countplot(data = hotel_booking_df, x = 'deposit_type', order = hotel_booking_df['deposit_type'].value_counts().index)
plt.title('Graph showing types of deposits', fontsize = 20 , weight= 'bold')
plt.ylabel('Count' , weight= 'bold')
plt.xlabel('Deposit Type', weight= 'bold' )
# Out:
# Text(0.5, 0, 'Deposit Type')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Countplot chart is used to show the percentage distribution visually

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# <LI>More than 85% of hotels have "No Deposit" policy.
# <LI>Refundable is not visible in the graph,it's almost 0

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# ###**Question-19-Which type of guests (single , couple or family) are often visiting to hotels?**

# %%
plt.figure(figsize=(5,5))
ax=sns.countplot(x=hotel_booking_df['hotel'], hue=hotel_booking_df['guest_category'])
ax.set_title('hotel v/s guest_category')
#annot_percent(plot)
plt.show()

# %%
def Typeof(hotel_booking_df) :
    if hotel_booking_df['adults'] == 1 and hotel_booking_df['children'] == 0 and hotel_booking_df['babies'] == 0 :
        return 'Single'
    if hotel_booking_df['adults'] == 2 and hotel_booking_df['children'] == 0 and hotel_booking_df['babies'] == 0 :
        return 'Couple'
    if hotel_booking_df['adults'] > 2 and hotel_booking_df['children'] == 0 and hotel_booking_df['babies'] == 0 :
        return 'Group or Friends'
    else:
        return 'Family'
hotel_booking_df['guest_type'] = hotel_booking_df.apply(Typeof, axis=1)
hotel_booking_df['guest_type'].value_counts().plot(kind = 'pie', autopct='%.2f%%')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# ***
# <b>Here pie chart and countplot is used to count the the percentage for each type of guests category
# <li>2 adutts are treated as couple
# <li>1 adult without any child is treated as Single
# <li>more than 2 adults with or without children are treated as family <br></b>

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# <b>
# <ol>
# <li> According to the pie chart , one can find that  most of the guests booking hotels are couple having no child or baby
# <li> Most customers book hotels for two people (couples). Customers prefer city hotels over resorts for family bookings. <li>  A city hotel is preferred when booking for a single person.
# </ol>
# </b>

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **yes, it will help to manage hotel management to make more policies for the couples**

# %% [markdown]
# ###**Question-20-Is not having a reserved room assigned a reason for booking cancellations?**

# %%
## Plotting count plot for is_canceled in terms of reserved_room_assigned
plt.figure(figsize=(5,5))
#plot=plt.subplot(111)
ax=sns.countplot(x=hotel_booking_df['is_canceled'], hue=hotel_booking_df['reserved_room_assigned'])
ax.set_title('is_canceled v/s reserved_room_assigned')
#annot_percent(plot)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# ***Here I picked the countplot grapht to count the number of cancelllations and booking wrt to rooms assigned***

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# ***The inability to assign a reserved room to a customer is not grounds for cancellation. Less than 1% of people who cancelled their booking when the reserved room was not assigned.***

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# ****

# %% [markdown]
# ###**Question-21-Is the high lead_time a reason for booking cancellations??**

# %%
# Plotting count plot for lead_time_category in terms of is_canceled
plt.figure(figsize=(5,5))
plot=plt.subplot(111)
ax=sns.countplot(x=hotel_booking_df['lead_time_category'], hue=hotel_booking_df['is_canceled'])
ax.set_title('lead_time_category v/s is_canceled')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# ***Here I picked the countplot grapht to count the number of cancelllations and booking wrt to lead time***

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# ***Less lead time means fewer cancellations. Customers who book hotels more than 15 days in advance are more likely to cancel their booking. Booking cancellations are not caused by a longer Lead time.***

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# ****

# %% [markdown]
# ###**Question-22-Which distribution channels have the most cancellations of bookings?**

# %%
# Plotting a count plot for distribution channels in terms of the number of booking cancellations
plt.figure(figsize=(5,5))
#plot=plt.subplot(111)
ax=sns.countplot(x=hotel_booking_df['distribution_channel'], hue=hotel_booking_df['is_canceled'])
ax.set_title('% of booking cancellations per distribution channel')
#annot_percent(plot)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# ***Here I picked the countplot grapht to count the number of cancelllations and booking wrt to distribution channel***

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# <b><i>
# <li>The majority of canceled bookings were made through the TA/TO distribution channel.
# <li>Bookings made through the Direct, Corporate, and GDS distribution channels are extremely unlikely to be canceled.
# </b></i>

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# ****

# %% [markdown]
# ###**Question-23-What is the most common number of nights booked by customers?**

# %%
# Plotting count plot for total_stays
plt.figure(figsize=(15,8))
#plot=plt.subplot(111)
ax=sns.countplot(x=hotel_booking_df['total_night'])
ax.set_title('number of nights preferred to stay by % of customers')
#annot_percent(plot)
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# ***Here I picked the countplot grapht to count the number of total nights booked by the customers***

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# <b><i>
# <li>The majority of the guests are staying at the hotel for three nights. Customers who book hotels for more than one week are very rare. Most hotel bookings are for less than 7 nights. The hotel should pay more attention to keeping reservations available for less than 7 nights to not lose customers and to generate more revenue.</b></i>

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# ****

# %% [markdown]
# ###**Question-24-Which customer type generates more revenue in terms of hotel types?**

# %%
# Plotting bar plot for diffrent customers type against ADR
plt.figure(figsize=(5,5))
plot=plt.subplot(1,1,1)
ax=sns.barplot(x=hotel_booking_df['customer_type'], y=hotel_booking_df['adr'], hue=hotel_booking_df['hotel'])
ax.set_title('bar plot of customer_type vs. adr in terms of hotel types')
#annot_percent(plot)
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# ***Here I picked the countplot grapht to count the number of total nights booked by the customers***

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# ***City hotels generate more revenue (54.86%) than resort hotels (45.14%). Transient customers who book rooms for a short period of time generate more revenue than other types of customers.***

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# ****

# %% [markdown]
# ###**Question-25-What is the most common number of special requests made by customers, and what kind of customer are they?**

# %%
# Plotting count plot for total_of_special_requests in terms of different guest type
plt.figure(figsize=(10,5))
plot=plt.subplot(111)
ax=sns.countplot(x=hotel_booking_df['total_of_special_requests'], hue=hotel_booking_df['guest_category'])
ax.set_title('total_of_special_requests by % of customers')
#annot_percent(plot)
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# ***Here I picked the countplot grapht to count the number of total special requests by the customers***

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Approximately half of all customers do not make special requests. Customers frequently make one special request. Couples make the majority of special requests. Bookings made for single people are not more requested for special requests than those made for couples, followed by family and business events.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# ****

# %% [markdown]
# ###**Question-26-Does a longer waiting period cause the cancellation of bookings?**

# %%
#Selecting bookings with non zero waiting time
waiting_time=hotel_booking_df[hotel_booking_df['days_in_waiting_list']!=0]

#ploting graph

plt.figure(figsize=(5,5))
ax=sns.kdeplot(x=waiting_time['days_in_waiting_list'], hue=waiting_time['is_canceled'])
ax.set_title('days_in_waiting_list')
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# ***Here I picked the countplot grapht to count the number of total special requests by the customers***

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **The majority of canceled bookings have a waiting period of less than 150 days, but those that are not canceled bookings by customers have a waiting period of less than 150 days, which has a higher density than the canceled bookings. So a longer waiting period is not a reason for booking cancellation**

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# ****

# %% [markdown]
# ###**Correlation Heatmap**

# %%
# Correlation Heatmap visualization code
corr_df = hotel_booking_df[['is_canceled','lead_time','previous_cancellations','previous_bookings_not_canceled','booking_changes','days_in_waiting_list','adr','required_car_parking_spaces','total_of_special_requests','adults','children','babies']]
corr_mat = corr_df.corr()
f, ax = plt.subplots(figsize=(12, 7))
sns.heatmap(corr_mat,vmax=0.8,annot = True,fmt='.2f')
# Out:
# <Axes: >

# %% [markdown]
# #### 1. Why did you pick the specific chart?

# %% [markdown]
# ***I have used here  correlation heatmap as it is the best graphical tool that uses colors to show the correlation between multiple variables. I want to understand the relationship between the various numerical entities of the dataset. Heatmaps represent data using colors to visualize the intensity or value of each data point in a matrix.***

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ###**Pair Plot**

# %%
# Pair Plot visualization code
new_df2=hotel_booking_df[['hotel','is_canceled','lead_time','arrival_date_year','arrival_date_month','meal','market_segment','distribution_channel','reserved_room_type',
       'assigned_room_type','deposit_type','days_in_waiting_list', 'customer_type', 'adr','total_night',
       'total_people', 'total_childrens', 'reserved_room_assigned',
       'guest_category', 'lead_time_category']]

# Plotting pair plot for dataset
plt.figure(figsize=(10,8))
ax=sns.pairplot(new_df2)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# **A pair plot, also known as a scatterplot matrix, is a matrix of graphs that enables the visualization of the relationship between each pair of variables in a dataset. It combines both histogram and scatter plots, providing a unique overview of the dataset's distributions and correlations.Pair plots play a crucial role in EDA by facilitating a quick, yet thorough, examination of how variables interact with each other. They enable data scientists to:
# Visualize distributions: Understand the distribution of single variables.
# Identify relationships: Observe linear or nonlinear relationships between variables.
# Detect anomalies: Spot outliers that may indicate errors or unique insights**

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# <li>We can conclude from the relationship between lead_time and is_canceled that a longer lead time does not result in cancellations.
# <li>We can conclude from the lead_time and arrival_date_year graphs that people were consistently interested in booking rooms in advance in 2015, 2016, and 2017.
# <li>According to the graph of arrival_date_year and days_in_waiting_list, 2016 had the longest waiting period for room bookings.
# <li>We can conclude from the graph of ADR and days_in_waiting_list that a short minimum waiting period for bookings results in a high ADR.
# <li>From the graph of "is_canceled" and "days_in_waiting_list," we conclude that waiting for bookings is not a reason for booking cancellation.

# %% [markdown]
# # **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# <h4>The primary goal of this EDA is to reduce the cancellation rate and thereby increasing the profitibility of the hotels, so so major steps to be taken are as follows.:
#
# <p align="justify"><li> A city hotel has more bookings than a resort. Offer packages and promotions to promote bookings for the resort hotel.
# <p align="justify"><Li>BB is the most requested food. The hotel should maintain food quality while also offering discounts on other foods to promote other food types, reducing the burden on kitchen management and keeping a variety of food options available to customers.<p align="justify"><li>Most of the bookings are made through the online platform. Hotels can cut costs by eliminating market segments such as complementary and aviation because bookings through these segments are very low<p align="justify"><Li>Because most bookings made through TA/TO distribution are followed by corporate distribution, hotels should invest in both TA/TO and corporate distribution channels. The GDS distribution channel can be eliminated by hoteliers because bookings made through it are extremely low.<p align="justify"><Li>Very few customers (3.86%) visited again. So hotels can increase repeat bookings by offering the right repeat booking incentives, understanding the motivations behind repeat bookings, marketing to your guests’ past interests, and assessing past bookings to identify priority guests.<p align="justify"><li>Because rooms A and D are the most popular with customers, the hotel should maintain their quality. The hotel should promote rooms E, F, and G to increase demand by offering discounts. Because customers do not prefer to book room types B, C, H, and L, the hotel can eliminate them, lowering the cost of these rooms<p align="justify"><li>Customers do not want to pay a pre-deposit for a reservation. Hotels should promote advance deposits because not only does an advance deposit allow you to recognize revenue faster, it also greatly decreases the risk of cancellations<p align="justify"><li>Because 3 and 8 parking spaces were rarely requested by customers, hotels can only keep bookings for 1 and 2 parking spaces to save money.<li>15% of customers were not given reserved rooms. Make sure that guests get the rooms they have booked.<p align="justify"><li>Almost 25% of customers cancelled their bookings. Hotel should implement a cancellation policy, discount on confirmed bookings, and send booking reminders to guests to reduce booking cancellations.<p align="justify"><li>People typically book rooms for two people, so encourage family and group bookings. You can maximize revenue by promoting it with a discounted offer for group bookings<p align="justify"><li> The majority of guests come from western Europe countries. We should spend asignificant amount of our budget on those area.
# <p align="justify"><li>July- August are the busiest and profitable months for both of hotels. Hotel must do some campains for remaining month also.
# <p align="justify"><li>Couples are the most common guests for hotels, hence hotels can plan services according to couples needs to increase revenue<p align="justify"><li>Most common stay length is less than 4 days and generally people prefer City hotel for short stay,but for long stays, Resort Hotel is preferred.<li> November,December,February and January are the months which has less bookining this period you can get rooms with less average daily rate.
# <li> The service and facilites must be improve because our nearly 50% bookings are online,but 25% from that are canceled these bookings.
# </ol>
# </h4>

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# <h2 <b>After the overall analysis we find :</h2>
#
# <h4>
# <Li> Around 61% bookings are for City hotel and 39% bookings are for Resort hotel, therefore City Hotel is busier than Resort Hotel.
# <li>Customers favored city hotels more than resort hotels by a margin of 61.07 percent.
# <li>One of the four reservations is canceled.
# <li>BB is the most requested food while the full board meal type is least preferred by guests.
# <li>The Online (internet) platform is used to make the majority of bookings.
# <li>The majority of the bookings are made using TA/TO, the leading distribution channel.
# <li>The customer wants Room A to be reserved the most.
# <li>The top country with the most number of bookings is PRT but at the same time large number of cancellations are having from that country.
# <li>When our daily rate are high that time multiple peoples are canceled there booking.
# <li>In January And December shows highest cancellation ratio. its more than the bookings.
# <li>July and August month have high Average daily price per person for resort hotel.
# <li>Most visitors are couples. Couples book hotels more than families, friends or singles
# <li>Customers do not wish to make a bookings with a pre-deposit
# <li>Customers (80%) favored making a hotel reservation for a short visit.
# <li>Only 10% of people require space to park their cars.
# <li>The inability to assign a reserved room to a customer is not grounds for cancellation.
# <li>Booking cancellations are not caused by a longer Lead time.
#
# <li>The busiest months for hotels are October and September. <li>There isn't a lengthy wait for reservations in July.
# <li>Not assigning a reserved room does not affect ADR.
# </ol>
# </b>
# </h4>

# %% [markdown]
# ### ***Hurrah! Successfully completed my EDA Capstone Project !!!***
